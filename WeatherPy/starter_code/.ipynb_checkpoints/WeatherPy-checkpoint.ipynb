# %% [markdown]
# # WeatherPy
#
# ---
#
# ## Starter Code to Generate Random Geographic Coordinates and a List of Cities

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time
from scipy.stats import linregress

# Impor the OpenWeatherMap API key
from api_keys import weather_api_key

# Import citipy to determine the cities based on latitude and longitude
from citipy import citipy

# %% [markdown]
# ### Generate the Cities List by Using the `citipy` Library

# %%
# Empty list for holding the latitude and longitude combinations
lat_lngs = []

# Empty list for holding the cities names
cities = []

# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

# Create a set of random lat and lng combinations
lats = np.random.uniform(lat_range[0], lat_range[1], size=1500)
lngs = np.random.uniform(lng_range[0], lng_range[1], size=1500)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
print(f"Number of cities in the list: {len(cities)}")
# Out:
# Number of cities in the list: 588

# %%
# Setting units for measure
units = "imperial"

# %% [markdown]
# ---

# %% [markdown]
# ## Requirement 1: Create Plots to Showcase the Relationship Between Weather Variables and Latitude
#
# ### Use the OpenWeatherMap API to retrieve weather data from the cities list generated in the started code

# %%
# Set the API base URL
url = "https://api.openweathermap.org/data/3.0/onecall?lat={lat}&lon={lon}&exclude={part}&appid={API key}"

# Define an empty list to fetch the weather data for each city
city_data = []

# Print to logger
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters
record_count = 1
set_count = 1

# Loop through all the cities in our list to fetch weather data
for i, city in enumerate(cities):
        
    # Group cities in sets of 50 for logging purposes
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 0

    # Create endpoint URL with each city
    city_url = f"{url}appid={weather_api_key}&units={units}"
    
    # Log the url, record, and set numbers
    print("Processing Record %s of Set %s | %s" % (record_count, set_count, city))

    # Add 1 to the record count
    record_count += 1

    # Run an API request for each of the cities
    try:
        # Parse the JSON and retrieve data
        weather_response = requests.get(city_url)
        city_weather = weather_response.json()

        # Parse out latitude, longitude, max temp, humidity, cloudiness, wind speed, country, and date
        city_lat = response_json["coord"]["lat"]
        city_lng = response_json["coord"]["lon"]
        city_max_temp = response_json["main"]["temp_max"]
        city_humidity = response_json["main"]["humidity"]
        city_clouds = response_json["clouds"]["all"]
        city_wind = response_json["wind"]["speed"]
        city_country = response_json["sys"]["country"]
        city_date = response_json["dt"]

        # Append the City information into city_data list
        city_data.append({"City": city, 
                          "Lat": city_lat, 
                          "Lng": city_lng, 
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                          "Date": city_date})

    # If an error is experienced, skip the city
    except:
        print("City not found. Skipping...")
        pass
              
# Indicate that Data Loading is complete 
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | bodo
# City not found. Skipping...
# Processing Record 2 of Set 1 | albany
# City not found. Skipping...
# Processing Record 3 of Set 1 | tiksi
# City not found. Skipping...
# Processing Record 4 of Set 1 | bechar
# City not found. Skipping...
# Processing Record 5 of Set 1 | san antonio de pale
# City not found. Skipping...
# Processing Record 6 of Set 1 | edinburgh of the seven seas
# City not found. Skipping...
# Processing Record 7 of Set 1 | adamstown
# City not found. Skipping...
# Processing Record 8 of Set 1 | yellowknife
# City not found. Skipping...
# Processing Record 9 of Set 1 | whitehorse
# City not found. Skipping...
# Processing Record 10 of Set 1 | longyearbyen
# City not found. Skipping...
# Processing Record 11 of Set 1 | yamazakicho-nakabirose
# City not found. Skipping...
# Processing Record 12 of Set 1 | blackmans bay
# City not found. Skipping...
# Processing Record 13 of Set 1 | avarua
# City not found. Skipping...
# Processing Record 14 of Set 1 | bethel
# City not found. Skipping...
# Processing Record 15 of Set 1 | wanganui
# City not found. Skipping...
# Processing Record 16 of Set 1 | kadugli
# City not found. Skipping...
# Processing Record 17 of Set 1 | lebu
# City not found. Skipping...
# Processing Record 18 of Set 1 | chonchi
# City not found. Skipping...
# Processing Record 19 of Set 1 | port-aux-francais
# City not found. Skipping...
# Processing Record 20 of Set 1 | camayenne
# City not found. Skipping...
# Processing Record 21 of Set 1 | cestos city
# City not found. Skipping...
# Processing Record 22 of Set 1 | lichinga
# City not found. Skipping...
# Processing Record 23 of Set 1 | san matias
# City not found. Skipping...
# Processing Record 24 of Set 1 | pandan
# City not found. Skipping...
# Processing Record 25 of Set 1 | kataragama
# City not found. Skipping...
# Processing Record 26 of Set 1 | poronaysk
# City not found. Skipping...
# Processing Record 27 of Set 1 | nova sintra
# City not found. Skipping...
# Processing Record 28 of Set 1 | iqaluit
# City not found. Skipping...
# Processing Record 29 of Set 1 | west island
# City not found. Skipping...
# Processing Record 30 of Set 1 | pala
# City not found. Skipping...
# Processing Record 31 of Set 1 | badger
# City not found. Skipping...
# Processing Record 32 of Set 1 | camarinas
# City not found. Skipping...
# Processing Record 33 of Set 1 | stanley
# City not found. Skipping...
# Processing Record 34 of Set 1 | margaret river
# City not found. Skipping...
# Processing Record 35 of Set 1 | port augusta
# City not found. Skipping...
# Processing Record 36 of Set 1 | cabo san lucas
# City not found. Skipping...
# Processing Record 37 of Set 1 | karratha
# City not found. Skipping...
# Processing Record 38 of Set 1 | uturoa
# City not found. Skipping...
# Processing Record 39 of Set 1 | utrik
# City not found. Skipping...
# Processing Record 40 of Set 1 | grytviken
# City not found. Skipping...
# Processing Record 41 of Set 1 | hithadhoo
# City not found. Skipping...
# Processing Record 42 of Set 1 | digras
# City not found. Skipping...
# Processing Record 43 of Set 1 | las terrenas
# City not found. Skipping...
# Processing Record 44 of Set 1 | bilibino
# City not found. Skipping...
# Processing Record 45 of Set 1 | dudinka
# City not found. Skipping...
# Processing Record 46 of Set 1 | ribeira grande
# City not found. Skipping...
# Processing Record 47 of Set 1 | chibougamau
# City not found. Skipping...
# Processing Record 48 of Set 1 | camana
# City not found. Skipping...
# Processing Record 49 of Set 1 | saipan
# City not found. Skipping...
# Processing Record 50 of Set 1 | klyuchi
# City not found. Skipping...
# Processing Record 0 of Set 2 | staryya darohi
# City not found. Skipping...
# Processing Record 1 of Set 2 | thompson
# City not found. Skipping...
# Processing Record 2 of Set 2 | waitangi
# City not found. Skipping...
# Processing Record 3 of Set 2 | lively
# City not found. Skipping...
# Processing Record 4 of Set 2 | auna
# City not found. Skipping...
# Processing Record 5 of Set 2 | copiapo
# City not found. Skipping...
# Processing Record 6 of Set 2 | ashburton
# City not found. Skipping...
# Processing Record 7 of Set 2 | kirensk
# City not found. Skipping...
# Processing Record 8 of Set 2 | coquimbo
# City not found. Skipping...
# Processing Record 9 of Set 2 | taiohae
# City not found. Skipping...
# Processing Record 10 of Set 2 | aykhal
# City not found. Skipping...
# Processing Record 11 of Set 2 | hamilton
# City not found. Skipping...
# Processing Record 12 of Set 2 | yuzhno-sukhokumsk
# City not found. Skipping...
# Processing Record 13 of Set 2 | south hedland
# City not found. Skipping...
# Processing Record 14 of Set 2 | punta arenas
# City not found. Skipping...
# Processing Record 15 of Set 2 | polyarnyy
# City not found. Skipping...
# Processing Record 16 of Set 2 | benguela
# City not found. Skipping...
# Processing Record 17 of Set 2 | san luis
# City not found. Skipping...
# Processing Record 18 of Set 2 | vila franca do campo
# City not found. Skipping...
# Processing Record 19 of Set 2 | callao
# City not found. Skipping...
# Processing Record 20 of Set 2 | zagora
# City not found. Skipping...
# Processing Record 21 of Set 2 | stephenville
# City not found. Skipping...
# Processing Record 22 of Set 2 | dalmatovo
# City not found. Skipping...
# Processing Record 23 of Set 2 | port elizabeth
# City not found. Skipping...
# Processing Record 24 of Set 2 | ushuaia
# City not found. Skipping...
# Processing Record 25 of Set 2 | prado
# City not found. Skipping...
# Processing Record 26 of Set 2 | anadyr
# City not found. Skipping...
# Processing Record 27 of Set 2 | ribeira brava
# City not found. Skipping...
# Processing Record 28 of Set 2 | kodiak
# City not found. Skipping...
# Processing Record 29 of Set 2 | luderitz
# City not found. Skipping...
# Processing Record 30 of Set 2 | shchuchyn
# City not found. Skipping...
# Processing Record 31 of Set 2 | keflavik
# City not found. Skipping...
# Processing Record 32 of Set 2 | pekanbaru
# City not found. Skipping...
# Processing Record 33 of Set 2 | mhamid
# City not found. Skipping...
# Processing Record 34 of Set 2 | puerto natales
# City not found. Skipping...
# Processing Record 35 of Set 2 | atafu village
# City not found. Skipping...
# Processing Record 36 of Set 2 | qui nhon
# City not found. Skipping...
# Processing Record 37 of Set 2 | kismayo
# City not found. Skipping...
# Processing Record 38 of Set 2 | kokshetau
# City not found. Skipping...
# Processing Record 39 of Set 2 | gadzhiyevo
# City not found. Skipping...
# Processing Record 40 of Set 2 | port mathurin
# City not found. Skipping...
# Processing Record 41 of Set 2 | dhulikhel
# City not found. Skipping...
# Processing Record 42 of Set 2 | itaituba
# City not found. Skipping...
# Processing Record 43 of Set 2 | sao vicente
# City not found. Skipping...
# Processing Record 44 of Set 2 | nicoya
# City not found. Skipping...
# Processing Record 45 of Set 2 | nar'yan-mar
# City not found. Skipping...
# Processing Record 46 of Set 2 | bor
# City not found. Skipping...
# Processing Record 47 of Set 2 | vorgashor
# City not found. Skipping...
# Processing Record 48 of Set 2 | georgetown
# City not found. Skipping...
# Processing Record 49 of Set 2 | college
# City not found. Skipping...
# Processing Record 0 of Set 3 | pisco
# City not found. Skipping...
# Processing Record 1 of Set 3 | kapuskasing
# City not found. Skipping...
# Processing Record 2 of Set 3 | vernon
# City not found. Skipping...
# Processing Record 3 of Set 3 | inga
# City not found. Skipping...
# Processing Record 4 of Set 3 | namtsy
# City not found. Skipping...
# Processing Record 5 of Set 3 | alapayevsk
# City not found. Skipping...
# Processing Record 6 of Set 3 | port said
# City not found. Skipping...
# Processing Record 7 of Set 3 | fale old settlement
# City not found. Skipping...
# Processing Record 8 of Set 3 | san agustin de valle fertil
# City not found. Skipping...
# Processing Record 9 of Set 3 | coihueco
# City not found. Skipping...
# Processing Record 10 of Set 3 | weno
# City not found. Skipping...
# Processing Record 11 of Set 3 | hadibu
# City not found. Skipping...
# Processing Record 12 of Set 3 | amursk
# City not found. Skipping...
# Processing Record 13 of Set 3 | ust-nera
# City not found. Skipping...
# Processing Record 14 of Set 3 | port douglas
# City not found. Skipping...
# Processing Record 15 of Set 3 | puerto ayora
# City not found. Skipping...
# Processing Record 16 of Set 3 | mukalla
# City not found. Skipping...
# Processing Record 17 of Set 3 | ancud
# City not found. Skipping...
# Processing Record 18 of Set 3 | virginia
# City not found. Skipping...
# Processing Record 19 of Set 3 | ilulissat
# City not found. Skipping...
# Processing Record 20 of Set 3 | kowon-up
# City not found. Skipping...
# Processing Record 21 of Set 3 | novodvinsk
# City not found. Skipping...
# Processing Record 22 of Set 3 | aasiaat
# City not found. Skipping...
# Processing Record 23 of Set 3 | dryden
# City not found. Skipping...
# Processing Record 24 of Set 3 | eusebio
# City not found. Skipping...
# Processing Record 25 of Set 3 | praia da vitoria
# City not found. Skipping...
# Processing Record 26 of Set 3 | tintafor
# City not found. Skipping...
# Processing Record 27 of Set 3 | starodub
# City not found. Skipping...
# Processing Record 28 of Set 3 | las heras
# City not found. Skipping...
# Processing Record 29 of Set 3 | saint-francois
# City not found. Skipping...
# Processing Record 30 of Set 3 | north guwahati
# City not found. Skipping...
# Processing Record 31 of Set 3 | ta`u
# City not found. Skipping...
# Processing Record 32 of Set 3 | tvoroyri
# City not found. Skipping...
# Processing Record 33 of Set 3 | vila velha
# City not found. Skipping...
# Processing Record 34 of Set 3 | saldanha
# City not found. Skipping...
# Processing Record 35 of Set 3 | ulsteinvik
# City not found. Skipping...
# Processing Record 36 of Set 3 | constantia
# City not found. Skipping...
# Processing Record 37 of Set 3 | panacan
# City not found. Skipping...
# Processing Record 38 of Set 3 | kawthoung
# City not found. Skipping...
# Processing Record 39 of Set 3 | kemijarvi
# City not found. Skipping...
# Processing Record 40 of Set 3 | baukau
# City not found. Skipping...
# Processing Record 41 of Set 3 | butzbach
# City not found. Skipping...
# Processing Record 42 of Set 3 | howrah
# City not found. Skipping...
# Processing Record 43 of Set 3 | petropavlovsk-kamchatsky
# City not found. Skipping...
# Processing Record 44 of Set 3 | khvansar
# City not found. Skipping...
# Processing Record 45 of Set 3 | miches
# City not found. Skipping...
# Processing Record 46 of Set 3 | nemuro
# City not found. Skipping...
# Processing Record 47 of Set 3 | nagqu
# City not found. Skipping...
# Processing Record 48 of Set 3 | wailua homesteads
# City not found. Skipping...
# Processing Record 49 of Set 3 | lakatoro
# City not found. Skipping...
# Processing Record 0 of Set 4 | mamuju
# City not found. Skipping...
# Processing Record 1 of Set 4 | yarmouth
# City not found. Skipping...
# Processing Record 2 of Set 4 | okha
# City not found. Skipping...
# Processing Record 3 of Set 4 | susuman
# City not found. Skipping...
# Processing Record 4 of Set 4 | along
# City not found. Skipping...
# Processing Record 5 of Set 4 | barguzin
# City not found. Skipping...
# Processing Record 6 of Set 4 | lihue
# City not found. Skipping...
# Processing Record 7 of Set 4 | ponta delgada
# City not found. Skipping...
# Processing Record 8 of Set 4 | karatau
# City not found. Skipping...
# Processing Record 9 of Set 4 | ciudad bolivar
# City not found. Skipping...
# Processing Record 10 of Set 4 | lensk
# City not found. Skipping...
# Processing Record 11 of Set 4 | 'ohonua
# City not found. Skipping...
# Processing Record 12 of Set 4 | yuanping
# City not found. Skipping...
# Processing Record 13 of Set 4 | mount gambier
# City not found. Skipping...
# Processing Record 14 of Set 4 | lorengau
# City not found. Skipping...
# Processing Record 15 of Set 4 | rio gallegos
# City not found. Skipping...
# Processing Record 16 of Set 4 | papatowai
# City not found. Skipping...
# Processing Record 17 of Set 4 | glenfield park
# City not found. Skipping...
# Processing Record 18 of Set 4 | machiques
# City not found. Skipping...
# Processing Record 19 of Set 4 | port blair
# City not found. Skipping...
# Processing Record 20 of Set 4 | ko pha ngan
# City not found. Skipping...
# Processing Record 21 of Set 4 | port lincoln
# City not found. Skipping...
# Processing Record 22 of Set 4 | oodweyne
# City not found. Skipping...
# Processing Record 23 of Set 4 | minas de marcona
# City not found. Skipping...
# Processing Record 24 of Set 4 | hawaiian paradise park
# City not found. Skipping...
# Processing Record 25 of Set 4 | macapa
# City not found. Skipping...
# Processing Record 26 of Set 4 | cam ranh
# City not found. Skipping...
# Processing Record 27 of Set 4 | santa maria del oro
# City not found. Skipping...
# Processing Record 28 of Set 4 | fort st. john
# City not found. Skipping...
# Processing Record 29 of Set 4 | saynshand
# City not found. Skipping...
# Processing Record 30 of Set 4 | aldama
# City not found. Skipping...
# Processing Record 31 of Set 4 | cloquet
# City not found. Skipping...
# Processing Record 32 of Set 4 | jackson
# City not found. Skipping...
# Processing Record 33 of Set 4 | walvis bay
# City not found. Skipping...
# Processing Record 34 of Set 4 | tam ky
# City not found. Skipping...
# Processing Record 35 of Set 4 | arraial do cabo
# City not found. Skipping...
# Processing Record 36 of Set 4 | ormara
# City not found. Skipping...
# Processing Record 37 of Set 4 | castillos
# City not found. Skipping...
# Processing Record 38 of Set 4 | martapura
# City not found. Skipping...
# Processing Record 39 of Set 4 | kone
# City not found. Skipping...
# Processing Record 40 of Set 4 | jamestown
# City not found. Skipping...
# Processing Record 41 of Set 4 | tzucacab
# City not found. Skipping...
# Processing Record 42 of Set 4 | macau
# City not found. Skipping...
# Processing Record 43 of Set 4 | kincardine
# City not found. Skipping...
# Processing Record 44 of Set 4 | boden
# City not found. Skipping...
# Processing Record 45 of Set 4 | caribou
# City not found. Skipping...
# Processing Record 46 of Set 4 | nelson bay
# City not found. Skipping...
# Processing Record 47 of Set 4 | sitka
# City not found. Skipping...
# Processing Record 48 of Set 4 | bulayevo
# City not found. Skipping...
# Processing Record 49 of Set 4 | byron bay
# City not found. Skipping...
# Processing Record 0 of Set 5 | nantucket
# City not found. Skipping...
# Processing Record 1 of Set 5 | kailua-kona
# City not found. Skipping...
# Processing Record 2 of Set 5 | udachny
# City not found. Skipping...
# Processing Record 3 of Set 5 | forster
# City not found. Skipping...
# Processing Record 4 of Set 5 | kachkanar
# City not found. Skipping...
# Processing Record 5 of Set 5 | kerikeri
# City not found. Skipping...
# Processing Record 6 of Set 5 | siwa oasis
# City not found. Skipping...
# Processing Record 7 of Set 5 | namibe
# City not found. Skipping...
# Processing Record 8 of Set 5 | geraldton
# City not found. Skipping...
# Processing Record 9 of Set 5 | lazaro cardenas
# City not found. Skipping...
# Processing Record 10 of Set 5 | fort bragg
# City not found. Skipping...
# Processing Record 11 of Set 5 | mata-utu
# City not found. Skipping...
# Processing Record 12 of Set 5 | crucecita
# City not found. Skipping...
# Processing Record 13 of Set 5 | rantauprapat
# City not found. Skipping...
# Processing Record 14 of Set 5 | olonkinbyen
# City not found. Skipping...
# Processing Record 15 of Set 5 | bredasdorp
# City not found. Skipping...
# Processing Record 16 of Set 5 | xilin hot
# City not found. Skipping...
# Processing Record 17 of Set 5 | swift current
# City not found. Skipping...
# Processing Record 18 of Set 5 | mazarron
# City not found. Skipping...
# Processing Record 19 of Set 5 | carutapera
# City not found. Skipping...
# Processing Record 20 of Set 5 | san luis de la loma
# City not found. Skipping...
# Processing Record 21 of Set 5 | scottburgh
# City not found. Skipping...
# Processing Record 22 of Set 5 | monrovia
# City not found. Skipping...
# Processing Record 23 of Set 5 | turpan
# City not found. Skipping...
# Processing Record 24 of Set 5 | nueve de julio
# City not found. Skipping...
# Processing Record 25 of Set 5 | mont-dore
# City not found. Skipping...
# Processing Record 26 of Set 5 | coahuayana de hidalgo
# City not found. Skipping...
# Processing Record 27 of Set 5 | port-vila
# City not found. Skipping...
# Processing Record 28 of Set 5 | san miguel
# City not found. Skipping...
# Processing Record 29 of Set 5 | kiffa
# City not found. Skipping...
# Processing Record 30 of Set 5 | holualoa
# City not found. Skipping...
# Processing Record 31 of Set 5 | puerto deseado
# City not found. Skipping...
# Processing Record 32 of Set 5 | bentota
# City not found. Skipping...
# Processing Record 33 of Set 5 | tranovaho
# City not found. Skipping...
# Processing Record 34 of Set 5 | whakatane
# City not found. Skipping...
# Processing Record 35 of Set 5 | kwang binh
# City not found. Skipping...
# Processing Record 36 of Set 5 | reyes
# City not found. Skipping...
# Processing Record 37 of Set 5 | svetlyy
# City not found. Skipping...
# Processing Record 38 of Set 5 | la ronge
# City not found. Skipping...
# Processing Record 39 of Set 5 | machakos
# City not found. Skipping...
# Processing Record 40 of Set 5 | invercargill
# City not found. Skipping...
# Processing Record 41 of Set 5 | ha'il
# City not found. Skipping...
# Processing Record 42 of Set 5 | ed damer
# City not found. Skipping...
# Processing Record 43 of Set 5 | bodden town
# City not found. Skipping...
# Processing Record 44 of Set 5 | salem
# City not found. Skipping...
# Processing Record 45 of Set 5 | dellys
# City not found. Skipping...
# Processing Record 46 of Set 5 | opuwo
# City not found. Skipping...
# Processing Record 47 of Set 5 | isafjordur
# City not found. Skipping...
# Processing Record 48 of Set 5 | gannan
# City not found. Skipping...
# Processing Record 49 of Set 5 | east london
# City not found. Skipping...
# Processing Record 0 of Set 6 | greenland
# City not found. Skipping...
# Processing Record 1 of Set 6 | labytnangi
# City not found. Skipping...
# Processing Record 2 of Set 6 | mwinilunga
# City not found. Skipping...
# Processing Record 3 of Set 6 | desterro
# City not found. Skipping...
# Processing Record 4 of Set 6 | mahdia
# City not found. Skipping...
# Processing Record 5 of Set 6 | tayu
# City not found. Skipping...
# Processing Record 6 of Set 6 | alice springs
# City not found. Skipping...
# Processing Record 7 of Set 6 | ixtapa
# City not found. Skipping...
# Processing Record 8 of Set 6 | mejit
# City not found. Skipping...
# Processing Record 9 of Set 6 | swakopmund
# City not found. Skipping...
# Processing Record 10 of Set 6 | upington
# City not found. Skipping...
# Processing Record 11 of Set 6 | naze
# City not found. Skipping...
# Processing Record 12 of Set 6 | mormugao
# City not found. Skipping...
# Processing Record 13 of Set 6 | nueva palestina
# City not found. Skipping...
# Processing Record 14 of Set 6 | nago
# City not found. Skipping...
# Processing Record 15 of Set 6 | nuuk
# City not found. Skipping...
# Processing Record 16 of Set 6 | lompoc
# City not found. Skipping...
# Processing Record 17 of Set 6 | qaqortoq
# City not found. Skipping...
# Processing Record 18 of Set 6 | altai
# City not found. Skipping...
# Processing Record 19 of Set 6 | hermanus
# City not found. Skipping...
# Processing Record 20 of Set 6 | kavieng
# City not found. Skipping...
# Processing Record 21 of Set 6 | colonia
# City not found. Skipping...
# Processing Record 22 of Set 6 | shenandoah
# City not found. Skipping...
# Processing Record 23 of Set 6 | thurso
# City not found. Skipping...
# Processing Record 24 of Set 6 | new norfolk
# City not found. Skipping...
# Processing Record 25 of Set 6 | tofol
# City not found. Skipping...
# Processing Record 26 of Set 6 | ulladulla
# City not found. Skipping...
# Processing Record 27 of Set 6 | alness
# City not found. Skipping...
# Processing Record 28 of Set 6 | el granada
# City not found. Skipping...
# Processing Record 29 of Set 6 | abu zabad
# City not found. Skipping...
# Processing Record 30 of Set 6 | maxixe
# City not found. Skipping...
# Processing Record 31 of Set 6 | tinghir
# City not found. Skipping...
# Processing Record 32 of Set 6 | emerald
# City not found. Skipping...
# Processing Record 33 of Set 6 | dolores
# City not found. Skipping...
# Processing Record 34 of Set 6 | hammerfest
# City not found. Skipping...
# Processing Record 35 of Set 6 | khandyga
# City not found. Skipping...
# Processing Record 36 of Set 6 | kichmengskiy gorodok
# City not found. Skipping...
# Processing Record 37 of Set 6 | rio grande
# City not found. Skipping...
# Processing Record 38 of Set 6 | bardai
# City not found. Skipping...
# Processing Record 39 of Set 6 | gangtok
# City not found. Skipping...
# Processing Record 40 of Set 6 | tavsanli
# City not found. Skipping...
# Processing Record 41 of Set 6 | argo
# City not found. Skipping...
# Processing Record 42 of Set 6 | sinabang
# City not found. Skipping...
# Processing Record 43 of Set 6 | karlskrona
# City not found. Skipping...
# Processing Record 44 of Set 6 | tralee
# City not found. Skipping...
# Processing Record 45 of Set 6 | flying fish cove
# City not found. Skipping...
# Processing Record 46 of Set 6 | saint-denis
# City not found. Skipping...
# Processing Record 47 of Set 6 | sabang
# City not found. Skipping...
# Processing Record 48 of Set 6 | laojunmiao
# City not found. Skipping...
# Processing Record 49 of Set 6 | arvi
# City not found. Skipping...
# Processing Record 0 of Set 7 | nouadhibou
# City not found. Skipping...
# Processing Record 1 of Set 7 | kaposvar
# City not found. Skipping...
# Processing Record 2 of Set 7 | san patricio
# City not found. Skipping...
# Processing Record 3 of Set 7 | urangan
# City not found. Skipping...
# Processing Record 4 of Set 7 | ariquemes
# City not found. Skipping...
# Processing Record 5 of Set 7 | legionowo
# City not found. Skipping...
# Processing Record 6 of Set 7 | ponca city
# City not found. Skipping...
# Processing Record 7 of Set 7 | sisimiut
# City not found. Skipping...
# Processing Record 8 of Set 7 | jibou
# City not found. Skipping...
# Processing Record 9 of Set 7 | bantogon
# City not found. Skipping...
# Processing Record 10 of Set 7 | taltal
# City not found. Skipping...
# Processing Record 11 of Set 7 | kingston
# City not found. Skipping...
# Processing Record 12 of Set 7 | dunedin
# City not found. Skipping...
# Processing Record 13 of Set 7 | labrador city
# City not found. Skipping...
# Processing Record 14 of Set 7 | oliver
# City not found. Skipping...
# Processing Record 15 of Set 7 | shimoda
# City not found. Skipping...
# Processing Record 16 of Set 7 | banyo
# City not found. Skipping...
# Processing Record 17 of Set 7 | pariaman
# City not found. Skipping...
# Processing Record 18 of Set 7 | la'ie
# City not found. Skipping...
# Processing Record 19 of Set 7 | adrogue
# City not found. Skipping...
# Processing Record 20 of Set 7 | margate
# City not found. Skipping...
# Processing Record 21 of Set 7 | okhotsk
# City not found. Skipping...
# Processing Record 22 of Set 7 | talnakh
# City not found. Skipping...
# Processing Record 23 of Set 7 | kenai
# City not found. Skipping...
# Processing Record 24 of Set 7 | cannonvale
# City not found. Skipping...
# Processing Record 25 of Set 7 | khovd
# City not found. Skipping...
# Processing Record 26 of Set 7 | qarshi
# City not found. Skipping...
# Processing Record 27 of Set 7 | broome
# City not found. Skipping...
# Processing Record 28 of Set 7 | adam
# City not found. Skipping...
# Processing Record 29 of Set 7 | smithers
# City not found. Skipping...
# Processing Record 30 of Set 7 | dakhla
# City not found. Skipping...
# Processing Record 31 of Set 7 | newman
# City not found. Skipping...
# Processing Record 32 of Set 7 | codrington
# City not found. Skipping...
# Processing Record 33 of Set 7 | guiuan
# City not found. Skipping...
# Processing Record 34 of Set 7 | barabai
# City not found. Skipping...
# Processing Record 35 of Set 7 | emirgazi
# City not found. Skipping...
# Processing Record 36 of Set 7 | saint-philippe
# City not found. Skipping...
# Processing Record 37 of Set 7 | toktogul
# City not found. Skipping...
# Processing Record 38 of Set 7 | el tocuyo
# City not found. Skipping...
# Processing Record 39 of Set 7 | lerwick
# City not found. Skipping...
# Processing Record 40 of Set 7 | san buenaventura
# City not found. Skipping...
# Processing Record 41 of Set 7 | creston
# City not found. Skipping...
# Processing Record 42 of Set 7 | talcahuano
# City not found. Skipping...
# Processing Record 43 of Set 7 | ambon
# City not found. Skipping...
# Processing Record 44 of Set 7 | frontera
# City not found. Skipping...
# Processing Record 45 of Set 7 | eleskirt
# City not found. Skipping...
# Processing Record 46 of Set 7 | pathein
# City not found. Skipping...
# Processing Record 47 of Set 7 | chehalis
# City not found. Skipping...
# Processing Record 48 of Set 7 | zungeru
# City not found. Skipping...
# Processing Record 49 of Set 7 | al kharijah
# City not found. Skipping...
# Processing Record 0 of Set 8 | camacupa
# City not found. Skipping...
# Processing Record 1 of Set 8 | palikir - national government center
# City not found. Skipping...
# Processing Record 2 of Set 8 | luanco
# City not found. Skipping...
# Processing Record 3 of Set 8 | wewak
# City not found. Skipping...
# Processing Record 4 of Set 8 | lan krabue
# City not found. Skipping...
# Processing Record 5 of Set 8 | kharovsk
# City not found. Skipping...
# Processing Record 6 of Set 8 | huasahuasi
# City not found. Skipping...
# Processing Record 7 of Set 8 | akureyri
# City not found. Skipping...
# Processing Record 8 of Set 8 | vilyuchinsk
# City not found. Skipping...
# Processing Record 9 of Set 8 | voi
# City not found. Skipping...
# Processing Record 10 of Set 8 | lucea
# City not found. Skipping...
# Processing Record 11 of Set 8 | bikenibeu village
# City not found. Skipping...
# Processing Record 12 of Set 8 | fuvahmulah
# City not found. Skipping...
# Processing Record 13 of Set 8 | alotau
# City not found. Skipping...
# Processing Record 14 of Set 8 | iskateley
# City not found. Skipping...
# Processing Record 15 of Set 8 | kaa-khem
# City not found. Skipping...
# Processing Record 16 of Set 8 | rio grande city
# City not found. Skipping...
# Processing Record 17 of Set 8 | al bawiti
# City not found. Skipping...
# Processing Record 18 of Set 8 | bonthe
# City not found. Skipping...
# Processing Record 19 of Set 8 | miguelopolis
# City not found. Skipping...
# Processing Record 20 of Set 8 | paraiso
# City not found. Skipping...
# Processing Record 21 of Set 8 | novosibirsk
# City not found. Skipping...
# Processing Record 22 of Set 8 | piton saint-leu
# City not found. Skipping...
# Processing Record 23 of Set 8 | chadron
# City not found. Skipping...
# Processing Record 24 of Set 8 | queenstown
# City not found. Skipping...
# Processing Record 25 of Set 8 | kapa'a
# City not found. Skipping...
# Processing Record 26 of Set 8 | hard bargain
# City not found. Skipping...
# Processing Record 27 of Set 8 | kolaras
# City not found. Skipping...
# Processing Record 28 of Set 8 | cargados carajos
# City not found. Skipping...
# Processing Record 29 of Set 8 | severo-yeniseyskiy
# City not found. Skipping...
# Processing Record 30 of Set 8 | hihifo
# City not found. Skipping...
# Processing Record 31 of Set 8 | hotan
# City not found. Skipping...
# Processing Record 32 of Set 8 | baki
# City not found. Skipping...
# Processing Record 33 of Set 8 | kill devil hills
# City not found. Skipping...
# Processing Record 34 of Set 8 | huanan
# City not found. Skipping...
# Processing Record 35 of Set 8 | chipinge
# City not found. Skipping...
# Processing Record 36 of Set 8 | st. john's
# City not found. Skipping...
# Processing Record 37 of Set 8 | haiku-pauwela
# City not found. Skipping...
# Processing Record 38 of Set 8 | leirvik
# City not found. Skipping...
# Processing Record 39 of Set 8 | tazacorte
# City not found. Skipping...
# Processing Record 40 of Set 8 | broken hill
# City not found. Skipping...
# Processing Record 41 of Set 8 | narvik
# City not found. Skipping...
# Processing Record 42 of Set 8 | toamasina
# City not found. Skipping...
# Processing Record 43 of Set 8 | torghay
# City not found. Skipping...
# Processing Record 44 of Set 8 | cidreira
# City not found. Skipping...
# Processing Record 45 of Set 8 | mitu
# City not found. Skipping...
# Processing Record 46 of Set 8 | kirakira
# City not found. Skipping...
# Processing Record 47 of Set 8 | nadi
# City not found. Skipping...
# Processing Record 48 of Set 8 | veraval
# City not found. Skipping...
# Processing Record 49 of Set 8 | sao martinho
# City not found. Skipping...
# Processing Record 0 of Set 9 | ailuk
# City not found. Skipping...
# Processing Record 1 of Set 9 | al-`ula
# City not found. Skipping...
# Processing Record 2 of Set 9 | lockport
# City not found. Skipping...
# Processing Record 3 of Set 9 | san pedro pochutla
# City not found. Skipping...
# Processing Record 4 of Set 9 | machico
# City not found. Skipping...
# Processing Record 5 of Set 9 | posto fiscal rolim de moura
# City not found. Skipping...
# Processing Record 6 of Set 9 | tanabe
# City not found. Skipping...
# Processing Record 7 of Set 9 | mikuni
# City not found. Skipping...
# Processing Record 8 of Set 9 | singkil
# City not found. Skipping...
# Processing Record 9 of Set 9 | murghob
# City not found. Skipping...
# Processing Record 10 of Set 9 | crane
# City not found. Skipping...
# Processing Record 11 of Set 9 | steamboat springs
# City not found. Skipping...
# Processing Record 12 of Set 9 | saint-georges
# City not found. Skipping...
# Processing Record 13 of Set 9 | chelsea
# City not found. Skipping...
# Processing Record 14 of Set 9 | ghat
# City not found. Skipping...
# Processing Record 15 of Set 9 | zelenchukskaya
# City not found. Skipping...
# Processing Record 16 of Set 9 | puerto san carlos
# City not found. Skipping...
# Processing Record 17 of Set 9 | igarka
# City not found. Skipping...
# Processing Record 18 of Set 9 | puerto madero
# City not found. Skipping...
# Processing Record 19 of Set 9 | south sioux city
# City not found. Skipping...
# Processing Record 20 of Set 9 | kyurdarmir
# City not found. Skipping...
# Processing Record 21 of Set 9 | zeist
# City not found. Skipping...
# Processing Record 22 of Set 9 | viligili
# City not found. Skipping...
# Processing Record 23 of Set 9 | kutum
# City not found. Skipping...
# Processing Record 24 of Set 9 | arboga
# City not found. Skipping...
# Processing Record 25 of Set 9 | antsiranana
# City not found. Skipping...
# Processing Record 26 of Set 9 | laascaanood
# City not found. Skipping...
# Processing Record 27 of Set 9 | dhangadhi
# City not found. Skipping...
# Processing Record 28 of Set 9 | vigan
# City not found. Skipping...
# Processing Record 29 of Set 9 | urengoy
# City not found. Skipping...
# Processing Record 30 of Set 9 | ola
# City not found. Skipping...
# Processing Record 31 of Set 9 | barah
# City not found. Skipping...
# Processing Record 32 of Set 9 | axim
# City not found. Skipping...
# Processing Record 33 of Set 9 | soio
# City not found. Skipping...
# Processing Record 34 of Set 9 | luba
# City not found. Skipping...
# Processing Record 35 of Set 9 | uliastay
# City not found. Skipping...
# Processing Record 36 of Set 9 | hilo
# City not found. Skipping...
# Processing Record 37 of Set 9 | page
# City not found. Skipping...
# Processing Record 38 of Set 9 | marat
# City not found. Skipping...
# Processing Record 39 of Set 9 | juan griego
# City not found. Skipping...
# Processing Record 40 of Set 9 | arteche
# City not found. Skipping...
# Processing Record 41 of Set 9 | murzuq
# City not found. Skipping...
# Processing Record 42 of Set 9 | al burayqah
# City not found. Skipping...
# Processing Record 43 of Set 9 | khilok
# City not found. Skipping...
# Processing Record 44 of Set 9 | grosseto
# City not found. Skipping...
# Processing Record 45 of Set 9 | rawai
# City not found. Skipping...
# Processing Record 46 of Set 9 | goure
# City not found. Skipping...
# Processing Record 47 of Set 9 | labuan lombok
# City not found. Skipping...
# Processing Record 48 of Set 9 | ahau
# City not found. Skipping...
# Processing Record 49 of Set 9 | kimbe
# City not found. Skipping...
# Processing Record 0 of Set 10 | kamyzyak
# City not found. Skipping...
# Processing Record 1 of Set 10 | delijan
# City not found. Skipping...
# Processing Record 2 of Set 10 | lockwood
# City not found. Skipping...
# Processing Record 3 of Set 10 | civitavecchia
# City not found. Skipping...
# Processing Record 4 of Set 10 | visakhapatnam
# City not found. Skipping...
# Processing Record 5 of Set 10 | noosa heads
# City not found. Skipping...
# Processing Record 6 of Set 10 | ocean pointe
# City not found. Skipping...
# Processing Record 7 of Set 10 | molochnoye
# City not found. Skipping...
# Processing Record 8 of Set 10 | sima
# City not found. Skipping...
# Processing Record 9 of Set 10 | plettenberg bay
# City not found. Skipping...
# Processing Record 10 of Set 10 | boende
# City not found. Skipping...
# Processing Record 11 of Set 10 | oroqen zizhiqi
# City not found. Skipping...
# Processing Record 12 of Set 10 | enewetak
# City not found. Skipping...
# Processing Record 13 of Set 10 | talara
# City not found. Skipping...
# Processing Record 14 of Set 10 | maceio
# City not found. Skipping...
# Processing Record 15 of Set 10 | sao felix do xingu
# City not found. Skipping...
# Processing Record 16 of Set 10 | natal
# City not found. Skipping...
# Processing Record 17 of Set 10 | biryusinsk
# City not found. Skipping...
# Processing Record 18 of Set 10 | istaravshan
# City not found. Skipping...
# Processing Record 19 of Set 10 | richards bay
# City not found. Skipping...
# Processing Record 20 of Set 10 | nyandoma
# City not found. Skipping...
# Processing Record 21 of Set 10 | alexandria
# City not found. Skipping...
# Processing Record 22 of Set 10 | la sarre
# City not found. Skipping...
# Processing Record 23 of Set 10 | amga
# City not found. Skipping...
# Processing Record 24 of Set 10 | berdigestyakh
# City not found. Skipping...
# Processing Record 25 of Set 10 | as sulayyil
# City not found. Skipping...
# Processing Record 26 of Set 10 | helston
# City not found. Skipping...
# Processing Record 27 of Set 10 | houghton
# City not found. Skipping...
# Processing Record 28 of Set 10 | paita
# City not found. Skipping...
# Processing Record 29 of Set 10 | port alfred
# City not found. Skipping...
# Processing Record 30 of Set 10 | carbonear
# City not found. Skipping...
# Processing Record 31 of Set 10 | williams lake
# City not found. Skipping...
# Processing Record 32 of Set 10 | acapulco de juarez
# City not found. Skipping...
# Processing Record 33 of Set 10 | zavodoukovsk
# City not found. Skipping...
# Processing Record 34 of Set 10 | hwange
# City not found. Skipping...
# Processing Record 35 of Set 10 | guerrero negro
# City not found. Skipping...
# Processing Record 36 of Set 10 | montepuez
# City not found. Skipping...
# Processing Record 37 of Set 10 | redencao
# City not found. Skipping...
# Processing Record 38 of Set 10 | arkhangel'sk
# City not found. Skipping...
# Processing Record 39 of Set 10 | ukhta
# City not found. Skipping...
# Processing Record 40 of Set 10 | micheweni
# City not found. Skipping...
# Processing Record 41 of Set 10 | prince rupert
# City not found. Skipping...
# Processing Record 42 of Set 10 | yeed
# City not found. Skipping...
# Processing Record 43 of Set 10 | santa maria do suacui
# City not found. Skipping...
# Processing Record 44 of Set 10 | guymon
# City not found. Skipping...
# Processing Record 45 of Set 10 | neiafu
# City not found. Skipping...
# Processing Record 46 of Set 10 | alesund
# City not found. Skipping...
# Processing Record 47 of Set 10 | thal
# City not found. Skipping...
# Processing Record 48 of Set 10 | palmer
# City not found. Skipping...
# Processing Record 49 of Set 10 | agat village
# City not found. Skipping...
# Processing Record 0 of Set 11 | truth or consequences
# City not found. Skipping...
# Processing Record 1 of Set 11 | kenora
# City not found. Skipping...
# Processing Record 2 of Set 11 | concepcion
# City not found. Skipping...
# Processing Record 3 of Set 11 | lae
# City not found. Skipping...
# Processing Record 4 of Set 11 | betio village
# City not found. Skipping...
# Processing Record 5 of Set 11 | pahlgam
# City not found. Skipping...
# Processing Record 6 of Set 11 | balaklava
# City not found. Skipping...
# Processing Record 7 of Set 11 | puerto penasco
# City not found. Skipping...
# Processing Record 8 of Set 11 | san sebastian de la gomera
# City not found. Skipping...
# Processing Record 9 of Set 11 | zheleznodorozhnyy
# City not found. Skipping...
# Processing Record 10 of Set 11 | hobyo
# City not found. Skipping...
# Processing Record 11 of Set 11 | kulia village
# City not found. Skipping...
# Processing Record 12 of Set 11 | tevragh zeina
# City not found. Skipping...
# Processing Record 13 of Set 11 | arhribs
# City not found. Skipping...
# Processing Record 14 of Set 11 | tazovsky
# City not found. Skipping...
# Processing Record 15 of Set 11 | molchanovo
# City not found. Skipping...
# Processing Record 16 of Set 11 | hameln
# City not found. Skipping...
# Processing Record 17 of Set 11 | nguigmi
# City not found. Skipping...
# Processing Record 18 of Set 11 | viedma
# City not found. Skipping...
# Processing Record 19 of Set 11 | ascension
# City not found. Skipping...
# Processing Record 20 of Set 11 | itoman
# City not found. Skipping...
# Processing Record 21 of Set 11 | kolwezi
# City not found. Skipping...
# Processing Record 22 of Set 11 | fortuna
# City not found. Skipping...
# Processing Record 23 of Set 11 | ugoofaaru
# City not found. Skipping...
# Processing Record 24 of Set 11 | sao joao da barra
# City not found. Skipping...
# Processing Record 25 of Set 11 | tolanaro
# City not found. Skipping...
# Processing Record 26 of Set 11 | tukrah
# City not found. Skipping...
# Processing Record 27 of Set 11 | itapecuru mirim
# City not found. Skipping...
# Processing Record 28 of Set 11 | kristiansund
# City not found. Skipping...
# Processing Record 29 of Set 11 | sosnovo-ozerskoye
# City not found. Skipping...
# Processing Record 30 of Set 11 | rocha
# City not found. Skipping...
# Processing Record 31 of Set 11 | oualidia
# City not found. Skipping...
# Processing Record 32 of Set 11 | hasaki
# City not found. Skipping...
# Processing Record 33 of Set 11 | puerto baquerizo moreno
# City not found. Skipping...
# Processing Record 34 of Set 11 | wynyard
# City not found. Skipping...
# Processing Record 35 of Set 11 | springbok
# City not found. Skipping...
# Processing Record 36 of Set 11 | senanga
# City not found. Skipping...
# Processing Record 37 of Set 11 | marte r. gomez (tobarito)
# City not found. Skipping...
# Processing Record 38 of Set 11 | jinghong
# City not found. Skipping...
# Processing Record 39 of Set 11 | tarawa
# City not found. Skipping...
# Processing Record 40 of Set 11 | mersa matruh
# City not found. Skipping...
# Processing Record 41 of Set 11 | muromtsevo
# City not found. Skipping...
# Processing Record 42 of Set 11 | hailar
# City not found. Skipping...
# Processing Record 43 of Set 11 | saudarkrokur
# City not found. Skipping...
# Processing Record 44 of Set 11 | bakanas
# City not found. Skipping...
# Processing Record 45 of Set 11 | veselyy
# City not found. Skipping...
# Processing Record 46 of Set 11 | taoudenni
# City not found. Skipping...
# Processing Record 47 of Set 11 | conceicao da barra
# City not found. Skipping...
# Processing Record 48 of Set 11 | bayanaul
# City not found. Skipping...
# Processing Record 49 of Set 11 | mountain home
# City not found. Skipping...
# Processing Record 0 of Set 12 | hayma'
# City not found. Skipping...
# Processing Record 1 of Set 12 | chicxulub puerto
# City not found. Skipping...
# Processing Record 2 of Set 12 | as saffaniyah
# City not found. Skipping...
# Processing Record 3 of Set 12 | antalaha
# City not found. Skipping...
# Processing Record 4 of Set 12 | tsengel
# City not found. Skipping...
# Processing Record 5 of Set 12 | ts'nori
# City not found. Skipping...
# Processing Record 6 of Set 12 | rembangan
# City not found. Skipping...
# Processing Record 7 of Set 12 | miri
# City not found. Skipping...
# Processing Record 8 of Set 12 | nokha
# City not found. Skipping...
# Processing Record 9 of Set 12 | tura
# City not found. Skipping...
# Processing Record 10 of Set 12 | tweed heads
# City not found. Skipping...
# Processing Record 11 of Set 12 | belmonte
# City not found. Skipping...
# Processing Record 12 of Set 12 | dwarka
# City not found. Skipping...
# Processing Record 13 of Set 12 | arauca
# City not found. Skipping...
# Processing Record 14 of Set 12 | kavaratti
# City not found. Skipping...
# Processing Record 15 of Set 12 | sao joao dos patos
# City not found. Skipping...
# Processing Record 16 of Set 12 | erenhot
# City not found. Skipping...
# Processing Record 17 of Set 12 | mount pearl
# City not found. Skipping...
# Processing Record 18 of Set 12 | waddan
# City not found. Skipping...
# Processing Record 19 of Set 12 | cockburn town
# City not found. Skipping...
# Processing Record 20 of Set 12 | las tablas
# City not found. Skipping...
# Processing Record 21 of Set 12 | brokopondo
# City not found. Skipping...
# Processing Record 22 of Set 12 | yanchep
# City not found. Skipping...
# Processing Record 23 of Set 12 | arawa
# City not found. Skipping...
# Processing Record 24 of Set 12 | thief river falls
# City not found. Skipping...
# Processing Record 25 of Set 12 | ust'-kulom
# City not found. Skipping...
# Processing Record 26 of Set 12 | rexburg
# City not found. Skipping...
# Processing Record 27 of Set 12 | batavia
# City not found. Skipping...
# Processing Record 28 of Set 12 | beira
# City not found. Skipping...
# Processing Record 29 of Set 12 | abraham's bay
# City not found. Skipping...
# Processing Record 30 of Set 12 | kamaishi
# City not found. Skipping...
# Processing Record 31 of Set 12 | portland
# City not found. Skipping...
# Processing Record 32 of Set 12 | menaka
# City not found. Skipping...
# Processing Record 33 of Set 12 | olenino
# City not found. Skipping...
# Processing Record 34 of Set 12 | magadan
# City not found. Skipping...
# Processing Record 35 of Set 12 | xining
# City not found. Skipping...
# Processing Record 36 of Set 12 | padang
# City not found. Skipping...
# Processing Record 37 of Set 12 | chinde
# City not found. Skipping...
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Convert the cities weather data into a Pandas DataFrame
city_data_df = pd.DataFrame.from_dict(city_data)

# Show Record Count
city_data_df.count()
# Out:
# Series([], dtype: int64)

# %%
# Display sample data
city_data_df.head()
# Out:
# Empty DataFrame
# Columns: []
# Index: []

# %%
# Export the City_Data into a csv
city_data_df.to_csv("./output_data/cities.csv", index_label="City_ID")
# Out:
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# Cell In[10], line 2
#       1 # Export the City_Data into a csv
# ----> 2 city_data_df.to_csv("./output_data/cities.csv", index_label="City_ID")
#
# File /opt/anaconda3/envs/dev/lib/python3.10/site-packages/pandas/core/generic.py:3902, in NDFrame.to_csv(self, path_or_buf, sep, na_rep, float_format, columns, header, index, index_label, mode, encoding, compression, quoting, quotechar, lineterminator, chunksize, date_format, doublequote, escapechar, decimal, errors, storage_options)
#    3891 df = self if isinstance(self, ABCDataFrame) else self.to_frame()
#    3893 formatter = DataFrameFormatter(
#    3894     frame=df,
#    3895     header=header,
#    (...)
#    3899     decimal=decimal,
#    3900 )
# -> 3902 return DataFrameRenderer(formatter).to_csv(
#    3903     path_or_buf,
#    3904     lineterminator=lineterminator,
#    3905     sep=sep,
#    3906     encoding=encoding,
#    3907     errors=errors,
#    3908     compression=compression,
#    3909     quoting=quoting,
#    3910     columns=columns,
#    3911     index_label=index_label,
#    3912     mode=mode,
#    3913     chunksize=chunksize,
#    3914     quotechar=quotechar,
#    3915     date_format=date_format,
#    3916     doublequote=doublequote,
#    3917     escapechar=escapechar,
#    3918     storage_options=storage_options,
#    3919 )
#
# File /opt/anaconda3/envs/dev/lib/python3.10/site-packages/pandas/io/formats/format.py:1152, in DataFrameRenderer.to_csv(self, path_or_buf, encoding, sep, columns, index_label, mode, compression, quoting, quotechar, lineterminator, chunksize, date_format, doublequote, escapechar, errors, storage_options)
#    1131     created_buffer = False
#    1133 csv_formatter = CSVFormatter(
#    1134     path_or_buf=path_or_buf,
#    1135     lineterminator=lineterminator,
#    (...)
#    1150     formatter=self.fmt,
#    1151 )
# -> 1152 csv_formatter.save()
#    1154 if created_buffer:
#    1155     assert isinstance(path_or_buf, StringIO)
#
# File /opt/anaconda3/envs/dev/lib/python3.10/site-packages/pandas/io/formats/csvs.py:247, in CSVFormatter.save(self)
#     243 """
#     244 Create the writer & save.
#     245 """
#     246 # apply compression and byte/text conversion
# --> 247 with get_handle(
#     248     self.filepath_or_buffer,
#     249     self.mode,
#     250     encoding=self.encoding,
#     251     errors=self.errors,
#     252     compression=self.compression,
#     253     storage_options=self.storage_options,
#     254 ) as handles:
#     255     # Note: self.encoding is irrelevant here
#     256     self.writer = csvlib.writer(
#     257         handles.handle,
#     258         lineterminator=self.lineterminator,
#    (...)
#     263         quotechar=self.quotechar,
#     264     )
#     266     self._save()
#
# File /opt/anaconda3/envs/dev/lib/python3.10/site-packages/pandas/io/common.py:739, in get_handle(path_or_buf, mode, encoding, compression, memory_map, is_text, errors, storage_options)
#     737 # Only for write methods
#     738 if "r" not in mode and is_path:
# --> 739     check_parent_directory(str(handle))
#     741 if compression:
#     742     if compression != "zstd":
#     743         # compression libraries do not like an explicit text-mode
#
# File /opt/anaconda3/envs/dev/lib/python3.10/site-packages/pandas/io/common.py:604, in check_parent_directory(path)
#     602 parent = Path(path).parent
#     603 if not parent.is_dir():
# --> 604     raise OSError(rf"Cannot save file into a non-existent directory: '{parent}'")
#
# OSError: Cannot save file into a non-existent directory: 'output_data'

# %%
# Read saved data
city_data_df = pd.read_csv("output_data/cities.csv", index_col="City_ID")

# Display sample data
city_data_df.head()

# %% [markdown]
# ### Create the Scatter Plots Requested
#
# #### Latitude Vs. Temperature

# %%
# Build scatter plot for latitude vs. temperature
plt.scatter(city_data_df["Lat"], city_data_df["Max Temp"], alpha=.8, edgecolors="k")

# Incorporate the other graph properties
plt.xlabel("Latitude")
plt.ylabel("Max Temperature (C)")
plt.title(f"City Latitude vs. Temperature ({date})")
plt.grid(True)
plt.tight_layout()

# Save the figure
plt.savefig("output_data/Fig1.png")

# Show plot
plt.show()

# %% [markdown]
# #### Latitude Vs. Humidity

# %%
# Build the scatter plots for latitude vs. humidity
plt.scatter(city_data_df["Lat"], city_data_df["Humidity"], alpha=.8, edgecolors="k")

# Incorporate the other graph properties
plt.xlabel("Latitude")
plt.ylabel("Humidity (%)")
plt.title(f"City Latitude vs. Humidity (%) ({date})")
plt.grid(True) 
plt.tight_layout()

# Save the figure
plt.savefig("output_data/Fig2.png")

# Show plot
plt.show()

# %% [markdown]
# #### Latitude Vs. Cloudiness

# %%
# Build the scatter plots for latitude vs. cloudiness
plt.scatter(city_data_df["Lat"], city_data_df["Cloudiness"], alpha=.8, edgecolors="k")

# Incorporate the other graph properties
plt.xlabel("Latitude")
plt.ylabel("Cloudiness")
plt.title(f"City Latitude vs. Cloudiness ({date})")
plt.grid(True) 
plt.tight_layout()

# Save the figure
plt.savefig("output_data/Fig3.png")

# Show plot
plt.show()

# %% [markdown]
# #### Latitude vs. Wind Speed Plot

# %%
# Build the scatter plots for latitude vs. wind speed
plt.scatter(city_data_df["Lat"], city_data_df["Wind Speed"], alpha=.8, edgecolors="k")

# Incorporate the other graph properties
plt.xlabel("Latitude")
plt.ylabel("Wind Speed (m/s)")
plt.title(f"City Latitude vs. Wind Speed ({date})")
plt.grid(True) 
plt.tight_layout()

# Save the figure
plt.savefig("output_data/Fig4.png")

# Show plot
plt.show()

# %% [markdown]
# ---
#
# ## Requirement 2: Compute Linear Regression for Each Relationship

# %%
# Define a function to create Linear Regression plots
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))

# %%
# Create a DataFrame with the Northern Hemisphere data (Latitude >= 0)
northern_hemi_df = city_data_df.loc[pd.to_numeric(city_data_df["Lat"]) > 0, :]

# Display sample data
northern_hemi_df.head()

# %%
# Create a DataFrame with the Southern Hemisphere data (Latitude < 0)
southern_hemi_df = city_data_df.loc[pd.to_numeric(city_data_df["Lat"]) < 0, :]

# Display sample data
southern_hemi_df.head()

# %% [markdown]
# ###  Temperature vs. Latitude Linear Regression Plot

# %%
# Linear regression on Northern Hemisphere
x_values = northern_hemi_df["Lat"]
y_values = northern_hemi_df["Max Temp"]
slope = linregress(x_values, y_values)
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))

# %%
# Linear regression on Southern Hemisphere
x_values = southern_hemi_df["Lat"]
y_values = southern_hemi_df["Max Temp"]
slope = linregress(x_values, y_values)
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))

# %% [markdown]
# **Discussion about the linear relationship:** YOUR RESPONSE HERE

# %% [markdown]
# ### Humidity vs. Latitude Linear Regression Plot

# %%
# Northern Hemisphere
plt.scatter(x_values, y_values)
plt.plot(x_values, regress_values, "-r")
plt.annotate(line_eq,(0,-20),fontsize=15,color="red")
plt.xlabel("Latitude")
plt.ylabel("Max Temp")
print(f'The r-value is {rvalue}')
print("-----------------------------------")
print("Observations about linear relationship:")
print("The regression displays a negative relationship between temperature and latitude")
print("In the northern hemisphere, as the latitude increases the distance from the equator increases")
print("As you move away from the equator, the max temperature decreases.")

# %%
# Southern Hemisphere
plt.scatter(x_values, y_values)
plt.plot(x_values, regress_values, "-r")
plt.annotate(line_eq,(-25,25),fontsize=15,color="red")
plt.xlabel("Latitude")
plt.ylabel("Humidity")
print(f'The r-value is {rvalue}')
print("-----------------------------------")
print("Observations about linear relationship:")
print("The relationship is slightly positive.")
print("Humidity increases as cities get closer to the equator.")

# %% [markdown]
# **Discussion about the linear relationship:** YOUR RESPONSE HERE

# %% [markdown]
# ### Cloudiness vs. Latitude Linear Regression Plot

# %%
# Northern Hemisphere
x_values = northern_hemi_df["Lat"]
y_values = northern_hemi_df["Cloudiness"]
slope = linregress(x_values, y_values)
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))

#Plot values
plt.scatter(x_values, y_values)
plt.plot(x_values, regress_values, "-r")
plt.annotate(line_eq,(40,20),fontsize=15,color="red")
plt.xlabel("Latitude")
plt.ylabel("Cloudiness")
print(f'The r-value is {rvalue}')
print("-----------------------------------")
print("Observations about linear relationship:")
print("There does not appear to be a coorelation between latitude and cloudiness.")

# %%
# Southern Hemisphere
x_values = southern_hemi_df["Lat"]
y_values = southern_hemi_df["Cloudiness"]
slope = linregress(x_values, y_values)
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))

#Plot values
plt.scatter(x_values, y_values)
plt.plot(x_values, regress_values, "-r")
plt.annotate(line_eq,(-25,15),fontsize=15,color="red")
plt.xlabel("Latitude")
plt.ylabel("Cloudiness")
print(f'The r-value is {rvalue}')
print("-----------------------------------")
print("Observations about linear relationship:")
print("There does not appear to be a coorelation between latitude and cloudiness.")

# %% [markdown]
# **Discussion about the linear relationship:** YOUR RESPONSE HERE

# %% [markdown]
# ### Wind Speed vs. Latitude Linear Regression Plot

# %%
# Northern Hemisphere
x_values = northern_hemi_df["Lat"]
y_values = northern_hemi_df["Wind Speed"]
slope = linregress(x_values, y_values)
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))

#Plot values
plt.scatter(x_values, y_values)
plt.plot(x_values, regress_values, "-r")
plt.annotate(line_eq,(15,10),fontsize=15,color="red")
plt.xlabel("Latitude")
plt.ylabel("Wind Speed")
print(f'The r-value is {rvalue}')
print("-----------------------------------")
print("Observations about linear relationship:")
print("There does not appear to be a coorelation between latitude and wind speed.")

# %%
# Southern Hemisphere
x_values = southern_hemi_df["Lat"]
y_values = southern_hemi_df["Wind Speed"]
slope = linregress(x_values, y_values)
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))

#Plot values
plt.scatter(x_values, y_values)
plt.plot(x_values, regress_values, "-r")
plt.annotate(line_eq,(-25,10),fontsize=15,color="red")
plt.xlabel("Latitude")
plt.ylabel("Wind Speed")
print(f'The r-value is {rvalue}')
print("-----------------------------------")
print("Observations about linear relationship:")
print("There does not appear to be a coorelation between latitude and wind speed.")

# %% [markdown]
# **Discussion about the linear relationship:** YOUR RESPONSE HERE
